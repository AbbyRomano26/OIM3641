# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
sales = 500
sales
# Out:
# 500

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]
sales.pop()
# Out:
# 625

# %%
integers = list(range(10,1,-1))
integers
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
customers = [
    {'name':'john', 'email': 'john@some.com'},
    {'name':'Ann', 'email': 'ann@some.com'}
]
customers[0]['email']
# Out:
# 'john@some.com'

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random

# %%
random.random()
# Out:
# 0.30108570006096

# %%
from random import random, normalvariate, choice

# %%
randint(1,10)
# Out:
# 3

# %%
normalvariate()
# Out:
# 0.6518300581165665

# %%
choice(["H", "T"])
# Out:
# 'T'

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\aromano1\OneDrive - Babson College\OIM3641\starterfiles

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
from datetime import date 

#important to use 1 not 01 python doesnt like that
today = date.today()
NYD = date(2027,1,1)
days = (NYD - today).days

print(days)
# Out:
# 339

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
principal = 1000
interest = 0.5
years = 5

#make sure correct range from 1-6 is same as 0-5
for year in range(1, years + 1):
    future_value = principal * (1 + interest) ** years 
print(f'future value is {future_value}')
# Out:
# future value is 7593.75

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %%
symbols = []

while True: 
    stock_symbol = input('Enter stock symbol: ')

    if stock_symbol == "":
        break
        
    if stock_symbol not in symbols: 
        symbols.append(stock_symbol)
    
    print(symbols)
# Out:
# Enter stock symbol:  googl
# ['googl']
# Enter stock symbol:  appl
# ['googl', 'appl']
# Enter stock symbol:

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
values = [58, 32, 37, 41, 36, 36, 54, 37, 25, 53]

#find mean, sum list divide by length of list
mean = sum(values) / len(values)

sum_sq_diff = 0
#find devition from the mean and square value
for v in values:
    sum_sq_diff += (v-mean) ** 2
print(sum_sq_diff)
# Out:
# 1020.9000000000001

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
file = open("jupyter.txt", "w")
file.write('this is a python test')
file.close()

file = open("jupyter.txt", "r")
text = file.read()
file.close()

print(text)
# Out:
# this is a python test

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
import random

die_one = random.randint(1,6)
die_two = random.randint(1,6)

sum = die_one + die_two
print(f'die one was {die_one}')
print(f'die two was {die_two}')
print(f'total is... {sum}!')
# Out:
# die one was 4
# die two was 5
# total is... 9!

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
values = [-1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2]

for v in values: 
    if v < 0: 
        print(v, 'is negative')
    else:
        print (v, 'is positive')
# Out:
# -1.59 is negative
# 2.36 is positive
# 1.69 is positive
# 1.13 is positive
# -0.91 is negative
# 1.48 is positive
# -0.34 is negative
# 1.31 is positive
# -0.74 is negative
# 0.2 is positive

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data
